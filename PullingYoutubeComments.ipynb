# %%
import os
import json
import googleapiclient.discovery
import requests
  
api_key="AIzaSyDugJ3NMj9r6GOes-_NBkTKzyILLpkrr4A"
video_id="R5dPvW7NMJE"
url = f"https://www.googleapis.com/youtube/v3/commentThreads?key={api_key}&textFormat=plainText&part=snippet&videoId={video_id}&maxResults=100"

data = requests.get(url).json()

# %%
data
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/HXA56Ak4XIf7GLCb7Vbxs2QAuiA"',
#  'nextPageToken': 'QURTSl9pMEdDWk9GRXVhTVVNTHZTLVM5RElqMFBGQzBzY19aQTVtcDhsbjFHa0tIZUVGRVk0dkZ6VjFZSl83SXktYlN1NWpmVFZwRGtNUDlPVElTblRkaUdqb2hZcm5MZURkLUhzT2o4SXlPMERvZkYwY3RiVktqZHFvTXc0M1I=',
#  'pageInfo': {'totalResults': 100, 'resultsPerPage': 100},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/eLm4s4ONvNmA2j9euUelbdyDpdY"',
#    'id': 'UgwunSbTb1GtiFrds8V4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/wQZuIEvAppaMkzvN4UDf6Mxg86Q"',
#      'id': 'UgwunSbTb1GtiFrds8V4AaABAg',
#      'snippet': {'authorDisplayName': 'disciprine',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJwhMsrwnp08q1k5xFFHI56ZXJqisB9S2Ow39A=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCnI3vmrvC9c6W5j8VxOwGDg',
#       'authorChannelId': {'value': 'UCnI3vmrvC9c6W5j8VxOwGDg'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'Corsair virtuoso was such a huge disappointment. Great mic audio. Awesome build quality.\n\nHowever completely unuseable audio since it has excessive artifacting. \n\nCompared against the cloud wireless and the arctis. Corsair was the only one with the issue',
#       'textOriginal': 'Corsair virtuoso was such a huge disappointment. Great mic audio. Awesome build quality.\n\nHowever completely unuseable audio since it has excessive artifacting. \n\nCompared against the cloud wireless and the arctis. Corsair was the only one with the issue',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:37:51.000Z',
#       'updatedAt': '2020-04-12T00:37:51.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/khRUaXMtRpLlm0tIofDSINdPmbM"',
#    'id': 'UgykpXZb0tDgu_GLoiF4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/peiqfUkYZBCzT18vMTW_N1PuONo"',
#      'id': 'UgykpXZb0tDgu_GLoiF4AaABAg',
#      'snippet': {'authorDisplayName': 'Alaister Ateca',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJyeK1fZo3j77gIO0zSF872yDsASg05D0_u9NA=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC6VeApstqvUBzG61cBcPd2A',
#       'authorChannelId': {'value': 'UC6VeApstqvUBzG61cBcPd2A'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'i dont understand  why all headset videos ignore the Corsair VOID RGB,  Its an great headset and the logitech G935 is  an joke compare to this',
#       'textOriginal': 'i dont understand  why all headset videos ignore the Corsair VOID RGB,  Its an great headset and the logitech G935 is  an joke compare to this',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:37:45.000Z',
#       'updatedAt': '2020-04-12T00:37:45.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/b-c98Ukiu6wvM6w7gyJL7iJAPfs"',
#    'id': 'UgzntbtAxaKJOnh3Nb94AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/Ge7U-zEfh_cPH3EgvEEHsoCmoNE"',
#      'id': 'UgzntbtAxaKJOnh3Nb94AaABAg',
#      'snippet': {'authorDisplayName': 'Gabby Tech',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJxFIXpicml6Z6Kmcnqb6ZOwYl9umTfOD_P6Dg=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCgSnGammOHpuo3j5t3FKe_g',
#       'authorChannelId': {'value': 'UCgSnGammOHpuo3j5t3FKe_g'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'i still use my senheiser gsp 500',
#       'textOriginal': 'i still use my senheiser gsp 500',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:37:30.000Z',
#       'updatedAt': '2020-04-12T00:37:30.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/g0OfxGVXsp33kbbQVcLfhwxIyfc"',
#    'id': 'Ugy-xmolxAcP1q2G3bN4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/peVwp175SpJvIkHCe19OvIRCtdI"',
#      'id': 'Ugy-xmolxAcP1q2G3bN4AaABAg',
#      'snippet': {'authorDisplayName': 'Joshua Mikesell',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJxA1NSQiMFevFMeUbkvceg-8XXA4f06DfT2vg=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCHtdfYNI2Cz5V8oK54iivrg',
#       'authorChannelId': {'value': 'UCHtdfYNI2Cz5V8oK54iivrg'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "I don't get the deal with wireless. I have some of the first run of Audeze Mobius,  always run wired",
#       'textOriginal': "I don't get the deal with wireless. I have some of the first run of Audeze Mobius,  always run wired",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:37:30.000Z',
#       'updatedAt': '2020-04-12T00:37:30.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/p3NVxfCCciwVDf0mCKEIMYxJPr8"',
#    'id': 'UgwSpfdJGCNzWIX2soF4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/k5bsCjjfsfgbHfmaq21WrWADa88"',
#      'id': 'UgwSpfdJGCNzWIX2soF4AaABAg',
#      'snippet': {'authorDisplayName': 'Alexandru Jucan',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJxUUC7Ib_9r5cLy0iYtSqaCZ-ThFK4j6aAWIw=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCO6IDzy0RhEP_VRBZBelEVw',
#       'authorChannelId': {'value': 'UCO6IDzy0RhEP_VRBZBelEVw'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'Confused as to why the Arctis pro wireless wasn’t included when the 7 was. Not the “best” steel series has in their lineup but okay',
#       'textOriginal': 'Confused as to why the Arctis pro wireless wasn’t included when the 7 was. Not the “best” steel series has in their lineup but okay',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2020-04-12T00:36:59.000Z',
#       'updatedAt': '2020-04-12T00:36:59.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/Xu9BscIDW85Y6p2wpXXqjh9o64Y"',
#    'id': 'Ugya-LhpHUDoTldLy_h4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/Lo493DBjecnXBZdjDHe6SNg-lmQ"',
#      'id': 'Ugya-LhpHUDoTldLy_h4AaABAg',
#      'snippet': {'authorDisplayName': 'virtuaconker85',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJz_bZhZFjLzwZaPUW77LZ7iLt-2l54jM-Tt9Q=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCMfMijfvrzE0YAq6inF_CAA',
#       'authorChannelId': {'value': 'UCMfMijfvrzE0YAq6inF_CAA'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'DO NOT GET THE LOGITECH  G935!!! \nSpeaking from experience with them they are NOT great at all as the range on them suck like only moving from one room to another can cause them to drop out, they are Very bulky and somewhat heavy causing long sessions to wear on the top of your head. As mentioned in the video they are of poor quality as they creak A LOT and you end up hearing it if you are say having a snack and the side panels do sometimes come off when slightly knocked.\nIm not happy with them at all and im now looking for something better but still havent found anything that could match the decent sound of the G935 (the only good thing going for them) and im kinda looking at the CORSAIR HS70 PRO but they dont have true 7.1 so yeah I dont know.',
#       'textOriginal': 'DO NOT GET THE LOGITECH  G935!!! \nSpeaking from experience with them they are NOT great at all as the range on them suck like only moving from one room to another can cause them to drop out, they are Very bulky and somewhat heavy causing long sessions to wear on the top of your head. As mentioned in the video they are of poor quality as they creak A LOT and you end up hearing it if you are say having a snack and the side panels do sometimes come off when slightly knocked.\nIm not happy with them at all and im now looking for something better but still havent found anything that could match the decent sound of the G935 (the only good thing going for them) and im kinda looking at the CORSAIR HS70 PRO but they dont have true 7.1 so yeah I dont know.',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:36:56.000Z',
#       'updatedAt': '2020-04-12T00:36:56.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/0zqBDMi5tfAG-gbmkYTYHzGswHA"',
#    'id': 'Ugx7R6ZHFOmut-3T8HJ4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/hoAn3opXwmRDiXgpl4g4_mHzm2s"',
#      'id': 'Ugx7R6ZHFOmut-3T8HJ4AaABAg',
#      'snippet': {'authorDisplayName': 'Benscko',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJyX9aE3FQfciIiee_E3_uEPJznzcFMQXAUU=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCqu7rknAjATVKtNA1kz-kdQ',
#       'authorChannelId': {'value': 'UCqu7rknAjATVKtNA1kz-kdQ'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "I use byerdynamic dt 770 pros and that won't change for a while",
#       'textOriginal': "I use byerdynamic dt 770 pros and that won't change for a while",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:35:57.000Z',
#       'updatedAt': '2020-04-12T00:35:57.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/NWLsR8AhCB2K3D_ESZibK_uSVlQ"',
#    'id': 'UgzvnQLk2vgUO1HG6jh4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/Bz7WLC4uXILwMJXsoXYIAh7wrUc"',
#      'id': 'UgzvnQLk2vgUO1HG6jh4AaABAg',
#      'snippet': {'authorDisplayName': 'besweeeet2',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJzOFX34qtcE5l5AeKQW6stAAkYu2ILksM8KWA=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC4CgRKThZk0G7sYvG7jt_HQ',
#       'authorChannelId': {'value': 'UC4CgRKThZk0G7sYvG7jt_HQ'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "I use a pair of Bose AE2 headphones I've had for a long time, paired with a Samson GoMic USB mic. Great audio in and out. Almost every headset mic I've heard is awful.",
#       'textOriginal': "I use a pair of Bose AE2 headphones I've had for a long time, paired with a Samson GoMic USB mic. Great audio in and out. Almost every headset mic I've heard is awful.",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:35:50.000Z',
#       'updatedAt': '2020-04-12T00:35:50.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/cE7ouUQ3jklSnqi-7S1o1UCteOU"',
#    'id': 'UgyTuPev_VPIZA0iEq94AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/_5EjF6D6tab4SbHaoF5T0PvR1Dc"',
#      'id': 'UgyTuPev_VPIZA0iEq94AaABAg',
#      'snippet': {'authorDisplayName': 'revox53',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJzl2XSZDWVOb_YMSbXKisXt9hY-QZBqk-6yRA=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC4XF_0ZrPYcFcOoEqFuUj6w',
#       'authorChannelId': {'value': 'UC4XF_0ZrPYcFcOoEqFuUj6w'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'sorry but those logitech headphones are absolute trash, this video is a writeoff due to this. Not to mention battery life of them are awful, connection issues suck, sound is terrible and comfort compared to the hyperX is subpar.',
#       'textOriginal': 'sorry but those logitech headphones are absolute trash, this video is a writeoff due to this. Not to mention battery life of them are awful, connection issues suck, sound is terrible and comfort compared to the hyperX is subpar.',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:35:20.000Z',
#       'updatedAt': '2020-04-12T00:36:13.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/5QH-wVXZbbeBUvaBnKH5_37Tifs"',
#    'id': 'UgwOHCZixUmHiBSZ3i14AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/X2fvKPEMBVUBrJuaoyKWsQ9sAaw"',
#      'id': 'UgwOHCZixUmHiBSZ3i14AaABAg',
#      'snippet': {'authorDisplayName': '407juan',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJxKKRoDisg8FKQqIT6NXQjSgjPGEN_P_axlLw=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCZEkv6qw7aZ8S1jWBRl7Irw',
#       'authorChannelId': {'value': 'UCZEkv6qw7aZ8S1jWBRl7Irw'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'the logitech one is horrible, the materials are bad they break easy, sound is horrible, software doesnt help at all, microphone is also weak',
#       'textOriginal': 'the logitech one is horrible, the materials are bad they break easy, sound is horrible, software doesnt help at all, microphone is also weak',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:35:09.000Z',
#       'updatedAt': '2020-04-12T00:35:09.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/VEbAGUvR_d-TE3ws3WyL2jaQbd8"',
#    'id': 'UgxRH9bEm2J8_R_60ll4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/BUdw8v5L3tW8K3jlQYb9nzxAJAI"',
#      'id': 'UgxRH9bEm2J8_R_60ll4AaABAg',
#      'snippet': {'authorDisplayName': 'CapsuleGraph',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJzf2ntKi_bpEPM0kB25yYh3mX7tpTuC-gh54Q=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCiWPV5OaO0hnO4U90kUUA6Q',
#       'authorChannelId': {'value': 'UCiWPV5OaO0hnO4U90kUUA6Q'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'Steelseries Arctis Pro Wireless are by far the best wireless gaming headphones',
#       'textOriginal': 'Steelseries Arctis Pro Wireless are by far the best wireless gaming headphones',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:34:25.000Z',
#       'updatedAt': '2020-04-12T00:34:25.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/nKoWZwu8pFXcCr8UiJ8Yz0ZRoP0"',
#    'id': 'UgysPLSiso3-cAmUf-t4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/9fmpPZ0ljnn5kFT6-gIzr7XHpHo"',
#      'id': 'UgysPLSiso3-cAmUf-t4AaABAg',
#      'snippet': {'authorDisplayName': 'Cian Boyling',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJy3QFCs7ofNLFNdIU2MVSTOiwOD94NoPSWaAA=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC9yGC628S4Kc0CEITUhllvg',
#       'authorChannelId': {'value': 'UC9yGC628S4Kc0CEITUhllvg'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'Arctis Pro wireless should’ve been included',
#       'textOriginal': 'Arctis Pro wireless should’ve been included',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:33:40.000Z',
#       'updatedAt': '2020-04-12T00:33:40.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/ExMc1u1m5cbm63cXuOIjL3yjsPo"',
#    'id': 'Ugy8Sv2sA3ZF-4n6l0J4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/hTPpfiTT9CNv9jpsd3oVFfnnaA4"',
#      'id': 'Ugy8Sv2sA3ZF-4n6l0J4AaABAg',
#      'snippet': {'authorDisplayName': 'Morgan and friends Animations',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJxkjYM6WFd4eTgaHO3nBYv9w46Y7ouno4D4_w=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC7oas-b_Pwpamzj3VE4acUg',
#       'authorChannelId': {'value': 'UC7oas-b_Pwpamzj3VE4acUg'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'I saw you in a commercial',
#       'textOriginal': 'I saw you in a commercial',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:33:30.000Z',
#       'updatedAt': '2020-04-12T00:33:30.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/M43F_EkNpkOooKcpaJn6rc4ft0Y"',
#    'id': 'UgwQsczovxQrkZfAcnp4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/pwNU8nnGrTnPuw6DPzvPHmpRtKA"',
#      'id': 'UgwQsczovxQrkZfAcnp4AaABAg',
#      'snippet': {'authorDisplayName': 'PinguFrosty',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJwPBExq0kze92BkgXROIEETpV5O1H1UhxFtoA=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCv0J5iFvuWpdrucedt91ZXQ',
#       'authorChannelId': {'value': 'UCv0J5iFvuWpdrucedt91ZXQ'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'what about the gsp 670 from sennheiser?',
#       'textOriginal': 'what about the gsp 670 from sennheiser?',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:33:28.000Z',
#       'updatedAt': '2020-04-12T00:33:28.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/1XDXUfmi6Ri-j6mRh9wxnGq2wsg"',
#    'id': 'Ugy1Su7Ttu87Jgpd0EV4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/P2UDtJ-cvMRsZEKH0WICcc6BEvM"',
#      'id': 'Ugy1Su7Ttu87Jgpd0EV4AaABAg',
#      'snippet': {'authorDisplayName': 'L_H1JAcK1nGJ YT',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJzqPRNerLNx_MA04H6Y0N8B6lxY_z01q2EbFw=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCeka4yNL9NweuqSoCpJIDJw',
#       'authorChannelId': {'value': 'UCeka4yNL9NweuqSoCpJIDJw'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "It's not a famous choice but Audeze LCD-GX is a gaming headphone....",
#       'textOriginal': "It's not a famous choice but Audeze LCD-GX is a gaming headphone....",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2020-04-12T00:33:27.000Z',
#       'updatedAt': '2020-04-12T00:33:27.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/I2sjdjYeYWmPGpQtRKd-B9GjjAU"',
#    'id': 'UgyZtVmkx6zp-9Ptc0l4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/tVBHyWZKoPItscprp8XM3Ctcb4c"',
#      'id': 'UgyZtVmkx6zp-9Ptc0l4AaABAg',
#      'snippet': {'authorDisplayName': 'Gogito',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJxoUK3npXWmbEbrFHpNSFHuGa9zj4JU0BhhdQ=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC7jKBxCgz3wK28M1vFz9CLw',
#       'authorChannelId': {'value': 'UC7jKBxCgz3wK28M1vFz9CLw'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "I'm just rocking my Logitech G Pro X headset and I have an Anker Soundsync Bluetooth 5.0 reciever/adapter for whenever I want to use it wireless. Overall it coated me about £110 so about $140",
#       'textOriginal': "I'm just rocking my Logitech G Pro X headset and I have an Anker Soundsync Bluetooth 5.0 reciever/adapter for whenever I want to use it wireless. Overall it coated me about £110 so about $140",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:32:50.000Z',
#       'updatedAt': '2020-04-12T00:34:17.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/11ndg6xhbMxPWlcVU6qoKxuZpFs"',
#    'id': 'UgyuEaprh9JqsJzW1qN4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/iiCy9d14CjHT2De6JItKqOkxZTk"',
#      'id': 'UgyuEaprh9JqsJzW1qN4AaABAg',
#      'snippet': {'authorDisplayName': 'Tucker Higgins',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJxrsmnTREsP24lITXHZPEyLkScrG6Cca-bk0w=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC33Lk1JTOKDlNRieRN-xkcA',
#       'authorChannelId': {'value': 'UC33Lk1JTOKDlNRieRN-xkcA'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "I'm thinking keep the wire and use those HyperX Cloud II for another decade",
#       'textOriginal': "I'm thinking keep the wire and use those HyperX Cloud II for another decade",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:32:48.000Z',
#       'updatedAt': '2020-04-12T00:32:48.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/VizpPP4x5Y9Hr9ndEv1c2ooj5Yo"',
#    'id': 'UgyJHFYCkTnaRqs-HM54AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/knQ_v5L1oKTN7JpNnKg96jtXu18"',
#      'id': 'UgyJHFYCkTnaRqs-HM54AaABAg',
#      'snippet': {'authorDisplayName': 'Hippy Treehugger',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJy_bUjvP3VqTuEAeFUpqEtrFTPtANVgWLhmJQ=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC13K2QT_PUBbksf6ZSN4bGQ',
#       'authorChannelId': {'value': 'UC13K2QT_PUBbksf6ZSN4bGQ'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "i have the logitec 935 and a little heads up mileage may very. the wireless function died in less than a year and i'm stuck using a aux cable for sound, furthermore when it starts dying you'll notice it by the syncing problem with audio levels and quality.",
#       'textOriginal': "i have the logitec 935 and a little heads up mileage may very. the wireless function died in less than a year and i'm stuck using a aux cable for sound, furthermore when it starts dying you'll notice it by the syncing problem with audio levels and quality.",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:32:38.000Z',
#       'updatedAt': '2020-04-12T00:32:38.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/CbikH-rhMhW4NXSBiApfTHaGwKk"',
#    'id': 'UgzjuC_E5U1zLDb2GNp4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/rgBVoj6or1HXyUndEO3aP0d2SOI"',
#      'id': 'UgzjuC_E5U1zLDb2GNp4AaABAg',
#      'snippet': {'authorDisplayName': 'Vales',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJx2JL4KsZdIL08Gn9aiNyuPhfT3eyX1YugKLA=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCG4QLMG7VtLpLcIIbTb5YhA',
#       'authorChannelId': {'value': 'UCG4QLMG7VtLpLcIIbTb5YhA'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'WHERE IS SENNHEISER?',
#       'textOriginal': 'WHERE IS SENNHEISER?',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:32:24.000Z',
#       'updatedAt': '2020-04-12T00:32:24.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/2i3wweakZX3keLsLCH_sMQ94RCM"',
#    'id': 'UgzDIiv-iHkVlhNfeEJ4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/M3T9VcrQUEwgXgl-DJ-K8GBk9DA"',
#      'id': 'UgzDIiv-iHkVlhNfeEJ4AaABAg',
#      'snippet': {'authorDisplayName': 'AARON BRYANT',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJytMta29G04twiYmXE4h2XUFOOaNqr_7u49LA=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC9Cvg070jpWyvhaW3wgGIKA',
#       'authorChannelId': {'value': 'UC9Cvg070jpWyvhaW3wgGIKA'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'How do the RIG 800LX compare to these headsets?',
#       'textOriginal': 'How do the RIG 800LX compare to these headsets?',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:32:24.000Z',
#       'updatedAt': '2020-04-12T00:32:24.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/n9i44Hq1meNjVhasQLru-sEFoHc"',
#    'id': 'Ugw-Tlp8T3Kt9XKYv_B4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/4qw5GAZphy29IdVc0nYIdRnCphE"',
#      'id': 'Ugw-Tlp8T3Kt9XKYv_B4AaABAg',
#      'snippet': {'authorDisplayName': 'Erik zwambach',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJxFmfphUtAQs2SeNW-XCDuTC0LOjRDs5GPn0g=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCugZViCCBdty8VhtZr1WOJw',
#       'authorChannelId': {'value': 'UCugZViCCBdty8VhtZr1WOJw'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'did the chance of equalizers in for my astro a50 like you guys had in the forum post and a hole new world opened up for me',
#       'textOriginal': 'did the chance of equalizers in for my astro a50 like you guys had in the forum post and a hole new world opened up for me',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:32:06.000Z',
#       'updatedAt': '2020-04-12T00:32:06.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/wLWjXI5vbuvKKex8MlCy7G0ziJk"',
#    'id': 'UgxRPSGZlBrujlXb13N4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/czSKZKVpF70ouIIHiUyXGJHxAPk"',
#      'id': 'UgxRPSGZlBrujlXb13N4AaABAg',
#      'snippet': {'authorDisplayName': 'John Douglas',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJyBYEMCxiRM-xJkPVdbY0IZcrgmF_2ZTFpO2Q=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC8UWgGU_B8LFPPQ9wdBaOvw',
#       'authorChannelId': {'value': 'UC8UWgGU_B8LFPPQ9wdBaOvw'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "the thing with logitec, my SO has been using them for ~5 years now, not a single headset has managed to reach it's end of warranty before it dies, she is now on her 5th set having been replaced and now this set is dying as well.\ntheir warranty however is superb and they just get swapped over, it's the hassle of having to DO it though. \nit's just annoying I can't help but why why they keep dying.",
#       'textOriginal': "the thing with logitec, my SO has been using them for ~5 years now, not a single headset has managed to reach it's end of warranty before it dies, she is now on her 5th set having been replaced and now this set is dying as well.\ntheir warranty however is superb and they just get swapped over, it's the hassle of having to DO it though. \nit's just annoying I can't help but why why they keep dying.",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:31:20.000Z',
#       'updatedAt': '2020-04-12T00:31:20.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/3uWbpeArR-g2Tw29-0jyYVceELM"',
#    'id': 'Ugx7X4q8rmyf6mthZ3F4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/o_4FL0VEufyimDz0A5qx16kd1y8"',
#      'id': 'Ugx7X4q8rmyf6mthZ3F4AaABAg',
#      'snippet': {'authorDisplayName': 'Max Nuij',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJwswhPml1hx-CP1Q5z-4pJ2fu5jxvjC7ULzdA=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCYjBveLCNYbphAGH9JlzWFA',
#       'authorChannelId': {'value': 'UCYjBveLCNYbphAGH9JlzWFA'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "I've had the Logitech G935 for a half year now. The qreekyness is something me and my friends haven't encountered yet with it. Sound is great and a lot of customisable options. Though the battery can be a tad bit disappointing.",
#       'textOriginal': "I've had the Logitech G935 for a half year now. The qreekyness is something me and my friends haven't encountered yet with it. Sound is great and a lot of customisable options. Though the battery can be a tad bit disappointing.",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2020-04-12T00:31:04.000Z',
#       'updatedAt': '2020-04-12T00:31:04.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/-7jVYZ4nfwV6ksm4SK7XT8FVIQg"',
#    'id': 'Ugy4MziN7RBfhZXE5yx4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/n2w524aT922mMxbZ3P8fLCuPPTs"',
#      'id': 'Ugy4MziN7RBfhZXE5yx4AaABAg',
#      'snippet': {'authorDisplayName': 'Matt Parsons',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJz4wlmGdQd_TnOHLLYmGaKt84jSo1HPtr582A=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC23eE_EM1u4Y_M_tqdlZEpA',
#       'authorChannelId': {'value': 'UC23eE_EM1u4Y_M_tqdlZEpA'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "You fellas seriously missed the boat with this one. 935's over A50's?! You've got to be kidding me. They sound worse, they're way less comfortable (45 minutes of use and my ears were killing me). They also feel unbelievably cheap. A50's sound even better when you replace the cloth ear pads with the closed variant.",
#       'textOriginal': "You fellas seriously missed the boat with this one. 935's over A50's?! You've got to be kidding me. They sound worse, they're way less comfortable (45 minutes of use and my ears were killing me). They also feel unbelievably cheap. A50's sound even better when you replace the cloth ear pads with the closed variant.",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:30:35.000Z',
#       'updatedAt': '2020-04-12T00:30:35.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/N79x36dEuS19fa2zv7td6uI7Ov8"',
#    'id': 'UgxKmyZ3gdTvRMwJ8u14AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/5JoIBy74FycD4o3oop94B_QxO6A"',
#      'id': 'UgxKmyZ3gdTvRMwJ8u14AaABAg',
#      'snippet': {'authorDisplayName': 'ysumx',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJwdd4pZ5mxmRVnn2TeMSCSq6raaI5TcQNf3sQ=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCRd2s9x6kx0zqLhmDuaJCqA',
#       'authorChannelId': {'value': 'UCRd2s9x6kx0zqLhmDuaJCqA'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'There’s no way that they used the virtuoso for more than an hour. The most uncomfortable headset ever.',
#       'textOriginal': 'There’s no way that they used the virtuoso for more than an hour. The most uncomfortable headset ever.',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:30:30.000Z',
#       'updatedAt': '2020-04-12T00:30:30.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/yDV6f6UnYvUns3AMEw7LVGf6SfY"',
#    'id': 'UgwJDU4RxeHYhZgKu7B4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/vraVeMZEZ2uT23cGAPbID97ksFQ"',
#      'id': 'UgwJDU4RxeHYhZgKu7B4AaABAg',
#      'snippet': {'authorDisplayName': 'Toller Tüp',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJzkjoI7WpL55ib3U0dlL6e3XWKj04cAdEkrWg=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCqlVKdjKFnNL9gsOYgvNFPw',
#       'authorChannelId': {'value': 'UCqlVKdjKFnNL9gsOYgvNFPw'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'I recommend just getting some good Headphones, like the Philips SHP 9500, and a USB or powered XLR Mic for best sound quality on your and your friends side. Stay away from Headsets!',
#       'textOriginal': 'I recommend just getting some good Headphones, like the Philips SHP 9500, and a USB or powered XLR Mic for best sound quality on your and your friends side. Stay away from Headsets!',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:29:32.000Z',
#       'updatedAt': '2020-04-12T00:29:32.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/DWRZwWuCWuHp9QsCJljD8UyMaPg"',
#    'id': 'UgyGzwj8LBISrsWXpQl4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/TksVWA7eBZpUNiCfhg9RqYD7bKI"',
#      'id': 'UgyGzwj8LBISrsWXpQl4AaABAg',
#      'snippet': {'authorDisplayName': 'Jason Hunt',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJx4xRVBV5Qg8CZnEk2tAPz_-_15tE-smLNMKQ=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCUBprB6WQ0KIVnYbofLXbZw',
#       'authorChannelId': {'value': 'UCUBprB6WQ0KIVnYbofLXbZw'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'Wouldthere be any issues with them working on next generation of consoles?',
#       'textOriginal': 'Wouldthere be any issues with them working on next generation of consoles?',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:29:29.000Z',
#       'updatedAt': '2020-04-12T00:29:29.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/pJOPSshEl6Ks-d8pfFLgBgADuJ4"',
#    'id': 'UgzLhe7wgB0ojrd4M0x4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/AJnuhhdpN3HUnLD0tE_nvLWH0xU"',
#      'id': 'UgzLhe7wgB0ojrd4M0x4AaABAg',
#      'snippet': {'authorDisplayName': 'NicosLeben',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJzXhwdiQfA2jTam8DEJoaulQC1c9Ge6uUhZuw=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCglt3UbDVHbd0_enzW3acZg',
#       'authorChannelId': {'value': 'UCglt3UbDVHbd0_enzW3acZg'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'Why are these "gaming" microphones always shitty as hell? Always clipping and distorted. Why can they not just sound at least acceptable? Is it so hard?',
#       'textOriginal': 'Why are these "gaming" microphones always shitty as hell? Always clipping and distorted. Why can they not just sound at least acceptable? Is it so hard?',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:29:07.000Z',
#       'updatedAt': '2020-04-12T00:29:07.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/uOqNETDm0wnupYwgCRK16j1gs84"',
#    'id': 'UgwAUq5hJIHEcQZKBYV4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/kUl6L2oMAcG3dlqXOwcnEl3ePOw"',
#      'id': 'UgwAUq5hJIHEcQZKBYV4AaABAg',
#      'snippet': {'authorDisplayName': 'alexpavelM',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJwKMHggfLpeyDC7EtocimMbmJKwtRaiqCkVNA=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCKOM5EcL2Gjv3H2V78txVnw',
#       'authorChannelId': {'value': 'UCKOM5EcL2Gjv3H2V78txVnw'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'This episode would have been perfect for a ridge wallet ad, considering that intro.',
#       'textOriginal': 'This episode would have been perfect for a ridge wallet ad, considering that intro.',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:28:46.000Z',
#       'updatedAt': '2020-04-12T00:28:46.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/3m3zUWoYkOijRzOi2zdjO0KD1wM"',
#    'id': 'UgzeSyXAI2NgHM8cIeF4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/w3t4L-VzcmdmfOzOGCfPWiaQPcg"',
#      'id': 'UgzeSyXAI2NgHM8cIeF4AaABAg',
#      'snippet': {'authorDisplayName': 'Raise Dennis',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJx97osrmNRhaIW9oP8jTAXgW8sWa-Pfow_1Vw=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC8X7lWiEh--J7fBIrzkXdXw',
#       'authorChannelId': {'value': 'UC8X7lWiEh--J7fBIrzkXdXw'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'Arctis pro wireless is way better than the a 50 it isn’t in this video and i use it. It’s so nice!',
#       'textOriginal': 'Arctis pro wireless is way better than the a 50 it isn’t in this video and i use it. It’s so nice!',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2020-04-12T00:28:41.000Z',
#       'updatedAt': '2020-04-12T00:28:41.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/KMjMDNO9_vjSVqhtDi_xR_4Z9Wk"',
#    'id': 'UgyyWKHhJE-kCM9HsdF4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/JI2fU7-Oebz1Ak1d3EAKN3rvydc"',
#      'id': 'UgyyWKHhJE-kCM9HsdF4AaABAg',
#      'snippet': {'authorDisplayName': 'Kamry',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJw2Iwm2cB46ECQt6pjcfsiyNOoWoVx66G_3LA=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UChPYSDscFpuQEixLemHo0gg',
#       'authorChannelId': {'value': 'UChPYSDscFpuQEixLemHo0gg'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "I love this Channel but this video was lacking. Don't put best in the tittle when you are using such a low sample pool.",
#       'textOriginal': "I love this Channel but this video was lacking. Don't put best in the tittle when you are using such a low sample pool.",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:27:57.000Z',
#       'updatedAt': '2020-04-12T00:27:57.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/dsIUJGe4polZZEAqtqWRPBBr5EA"',
#    'id': 'UgylmSF_gGsSPeJKg7d4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/BYKzt_OOIhV6MyI7knBNSJD82_k"',
#      'id': 'UgylmSF_gGsSPeJKg7d4AaABAg',
#      'snippet': {'authorDisplayName': 'Franco Castro',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJwfjBp6tFsi1ER_iaYhneZdd7U9-B3Iiw5I3g=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCaV-xZ3WqLh8Xvj1SxiREqw',
#       'authorChannelId': {'value': 'UCaV-xZ3WqLh8Xvj1SxiREqw'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'I have a Wh1000xm3 with a vroom microphone and works great.',
#       'textOriginal': 'I have a Wh1000xm3 with a vroom microphone and works great.',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:27:06.000Z',
#       'updatedAt': '2020-04-12T00:27:06.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/82TkLDBWyH6zj2Rj31zALaUG4tM"',
#    'id': 'UgzfZ7W0RuZepwj2pqZ4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/gPmdj3J5SjqB8Z6wPiWhJYm3Zrg"',
#      'id': 'UgzfZ7W0RuZepwj2pqZ4AaABAg',
#      'snippet': {'authorDisplayName': 'RS3 candlemage',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJxKxhzYPpYzRhFBI0eG9BA85YDeZU_8CbEizw=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCvNAn9TK8hEp-rq03Odo9jA',
#       'authorChannelId': {'value': 'UCvNAn9TK8hEp-rq03Odo9jA'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "i've been an avid music listener for well over a decade. i've spent anywhere between $10 to $150 on headphones and earphones. the best pair i've found build quality wise (that're still manufactured) is actually the best buy brand insignia bluetooth over ear headphones. my first pair of these lasted 4 years before i accidentally sat on them. my second pair lasted 3 years before i accidentally crushed them while falling. i'm on my 3rd pair now. can get for $20 if patient for a sale. if impatient it's $40. plug this into the best buy site: NS-CAHBTOE01....the only real con i can think of is that the lowest 2 volume settings while on bluetooth differ a bit too much.(too quiet vs slightly too loud) can still overcome that problem with detachable aux cord though.",
#       'textOriginal': "i've been an avid music listener for well over a decade. i've spent anywhere between $10 to $150 on headphones and earphones. the best pair i've found build quality wise (that're still manufactured) is actually the best buy brand insignia bluetooth over ear headphones. my first pair of these lasted 4 years before i accidentally sat on them. my second pair lasted 3 years before i accidentally crushed them while falling. i'm on my 3rd pair now. can get for $20 if patient for a sale. if impatient it's $40. plug this into the best buy site: NS-CAHBTOE01....the only real con i can think of is that the lowest 2 volume settings while on bluetooth differ a bit too much.(too quiet vs slightly too loud) can still overcome that problem with detachable aux cord though.",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:26:55.000Z',
#       'updatedAt': '2020-04-12T00:26:55.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/EOdd2hSgJgA3qDzE8Z3R9mHY90E"',
#    'id': 'UgyqySMvnMkGO0YM4ft4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/fJUPe9nv8wjBrYukF83p7NktcTE"',
#      'id': 'UgyqySMvnMkGO0YM4ft4AaABAg',
#      'snippet': {'authorDisplayName': 'Al Mohaimin Farabi',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJyt5d-pf6FJ8aD41LNtFSdTzU1BNWZabsPMKg=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCm7QgaFf5Ld_aXWL8m-8eLw',
#       'authorChannelId': {'value': 'UCm7QgaFf5Ld_aXWL8m-8eLw'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'What is the best headphone under 30$ to 45$',
#       'textOriginal': 'What is the best headphone under 30$ to 45$',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:25:49.000Z',
#       'updatedAt': '2020-04-12T00:25:49.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/9HPpPouDn-XFBDCeOP4_O9V5vyM"',
#    'id': 'UgzrFEHrglpE_y8BltF4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/qHB1j8dERie_UvFJUfYhsfKxp94"',
#      'id': 'UgzrFEHrglpE_y8BltF4AaABAg',
#      'snippet': {'authorDisplayName': 'Trahux',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJwl5zJEl3n9eCNo8ik08zIVNe6Tlx86-_r09w=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCT35MOt5llujomygPg4ylgw',
#       'authorChannelId': {'value': 'UCT35MOt5llujomygPg4ylgw'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'I really do hope that people understand that they mean gaming branded headsets in this video just in case before the same obnoxious gaming headset hate circlejerk starts and people start masturbating to their Beyerdynamics headphones with a ModMic.',
#       'textOriginal': 'I really do hope that people understand that they mean gaming branded headsets in this video just in case before the same obnoxious gaming headset hate circlejerk starts and people start masturbating to their Beyerdynamics headphones with a ModMic.',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-12T00:24:44.000Z',
#       'updatedAt': '2020-04-12T00:24:44.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/Tt0zpfD721jCJCAa7yRhg6v8r2I"',
#    'id': 'UgwLyTl-A4GYHwBmkSx4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/7_LrZnWjxgrKWc0fIsTxtPXkJgs"',
#      'id': 'UgwLyTl-A4GYHwBmkSx4AaABAg',
#      'snippet': {'authorDisplayName': 'Henrique Dias',
# ...
#      'snippet': {'authorDisplayName': 'captiankoala',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJxe2Cum9f01XotZHf8bAG43BBwa0fVDH5b56g=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCBfIPNYOZkUzc4GOCPT5fxA',
#       'authorChannelId': {'value': 'UCBfIPNYOZkUzc4GOCPT5fxA'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'arctis 7 instead of arctis pros????',
#       'textOriginal': 'arctis 7 instead of arctis pros????',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-11T23:59:52.000Z',
#       'updatedAt': '2020-04-11T23:59:52.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/ffFBVfi3Z6IwiWchw0I1UGC-h4I"',
#    'id': 'UgwuzINMvmeD8oS3UFp4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/oX-xZeZltQsn8yqE_rFjDJnYIOg"',
#      'id': 'UgwuzINMvmeD8oS3UFp4AaABAg',
#      'snippet': {'authorDisplayName': 'Naturalhighz',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJx9vAE3K5dmmKXB7pSEyxAVs_O2V-QbAfjzAA=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCOTOzS2CTppWTAZElImX9OQ',
#       'authorChannelId': {'value': 'UCOTOzS2CTppWTAZElImX9OQ'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "Just got the g533 from logitech and they are super squeaky and don't deal well with loud noises but range is great and fit is amazing. tried corsair h70 but their cups weren't deeper at the back so my ears didn't fit.",
#       'textOriginal': "Just got the g533 from logitech and they are super squeaky and don't deal well with loud noises but range is great and fit is amazing. tried corsair h70 but their cups weren't deeper at the back so my ears didn't fit.",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-11T23:59:21.000Z',
#       'updatedAt': '2020-04-11T23:59:21.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/LnYOhAjKwsluQu4bwK6lwnWKVSo"',
#    'id': 'UgzEZqLmKXeOgK_06Cx4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/iDTBquO7Og98YRmQ2JqgzjrHUi4"',
#      'id': 'UgzEZqLmKXeOgK_06Cx4AaABAg',
#      'snippet': {'authorDisplayName': 'Muehli25',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJwwYxansnfEn90BBJuSKYbGpBDjTbq7gzga0Q=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCIbkrF6UqMWBOeMuBE6MPhQ',
#       'authorChannelId': {'value': 'UCIbkrF6UqMWBOeMuBE6MPhQ'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "Beware of Logitech ghub, it's really not a full replacement for lgs and it's very buggy to this point",
#       'textOriginal': "Beware of Logitech ghub, it's really not a full replacement for lgs and it's very buggy to this point",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-11T23:59:02.000Z',
#       'updatedAt': '2020-04-11T23:59:02.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/KTnbvGAOVZH0jdSij6oin4NkvCw"',
#    'id': 'UgwqTO31E5Nv2i-SR8l4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/oS3JSS4SQei_GUH_D1oFBCABS9k"',
#      'id': 'UgwqTO31E5Nv2i-SR8l4AaABAg',
#      'snippet': {'authorDisplayName': 'Lumilicious',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJxnFWOjWogga4vwzNksALMs4WWPItiGfFxbDA=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCcE-0z3ijBGaICO7KyiZPXg',
#       'authorChannelId': {'value': 'UCcE-0z3ijBGaICO7KyiZPXg'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'The mics are all shit, the hyperx was the best... but still bad kinda bad.',
#       'textOriginal': 'The mics are all shit, the hyperx was the best... but still bad kinda bad.',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-11T23:58:45.000Z',
#       'updatedAt': '2020-04-11T23:58:45.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/E78HGvdGh4y8bJYUITgwzFofg2Q"',
#    'id': 'UgyfNyPug7awBD8tzVd4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/QUeh5T0hD69vMle6v1ezXAwUFRc"',
#      'id': 'UgyfNyPug7awBD8tzVd4AaABAg',
#      'snippet': {'authorDisplayName': 'Aubrey',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJziCnsyv_SiK5jCXbJbOnuz0G_RDvIhxVyIGA=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCt-bNJq_sMD_1lNxo7EW_Dw',
#       'authorChannelId': {'value': 'UCt-bNJq_sMD_1lNxo7EW_Dw'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'Wired video next pls',
#       'textOriginal': 'Wired video next pls',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-11T23:58:29.000Z',
#       'updatedAt': '2020-04-11T23:58:29.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/qcL2eg9zp3peGLEZu8o88NpZJzE"',
#    'id': 'UgyI-GFyN_5OJPk7gkV4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/mYbku3-dq5DL7oR3rsttiRa13h8"',
#      'id': 'UgyI-GFyN_5OJPk7gkV4AaABAg',
#      'snippet': {'authorDisplayName': 'LifeOnMarsden',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJxjfGhsyBskTZrs093bnrESwaapSTLuTkbDmg=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCNEWhoEsofYjqm3Hxbgx3gA',
#       'authorChannelId': {'value': 'UCNEWhoEsofYjqm3Hxbgx3gA'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "I personally don't really see the need for a wireless headset, headphones sure cos I wear them walking to work and stuff, but a headset? What's the point, when I'm gaming I'm literally just sat at my desk so why do I need a 30 foot range when I'm not going anywhere? Gimme open back wired headphones connected to a DAC/amp any day.",
#       'textOriginal': "I personally don't really see the need for a wireless headset, headphones sure cos I wear them walking to work and stuff, but a headset? What's the point, when I'm gaming I'm literally just sat at my desk so why do I need a 30 foot range when I'm not going anywhere? Gimme open back wired headphones connected to a DAC/amp any day.",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-11T23:58:24.000Z',
#       'updatedAt': '2020-04-11T23:58:24.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/WecMbKXftnpYI9xqyZrH_6OuiyM"',
#    'id': 'Ugwbs2Wabq7Carr-zVB4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/I3_XJBOuMtxdlOAszh8N1q3rigk"',
#      'id': 'Ugwbs2Wabq7Carr-zVB4AaABAg',
#      'snippet': {'authorDisplayName': 'Antonio Díaz Castrillo',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJw4wtte3wpS9pc1Ql03EwpKwKV8uYncn60qZw=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCA5GGB2e3hqoyCvng4ohB2w',
#       'authorChannelId': {'value': 'UCA5GGB2e3hqoyCvng4ohB2w'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'What song it is at 3:05 in the background?',
#       'textOriginal': 'What song it is at 3:05 in the background?',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-11T23:57:55.000Z',
#       'updatedAt': '2020-04-11T23:57:55.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/34HvHlGZ2to2xvX1dFpTd9oGRCw"',
#    'id': 'UgymUlGjMwSfl5ubtRt4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/Hiye2RqT9kFzyAU7uCUFpF3UziM"',
#      'id': 'UgymUlGjMwSfl5ubtRt4AaABAg',
#      'snippet': {'authorDisplayName': 'Frank Allotta',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJyFFRBXVYet6e3Sm-Y7HrCuXQfm1WQIj9EVoA=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCbDPryqshn0iTnC2foIR3Tw',
#       'authorChannelId': {'value': 'UCbDPryqshn0iTnC2foIR3Tw'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "The logitech set should last about 3 to 6 months. As soon as all the joints start disintegrating. Then you have to get a 3D printed part to fix them if you're out of warranty.  I have owned the logitech, the Steelseries Arctis 7 and the Arctis Pro. The Steelseries sets are better quality by far, and I have no idea the length you went to to make the mic on the Arctis 7 sound so terrible. Mine sounds way better than what you have sampled.",
#       'textOriginal': "The logitech set should last about 3 to 6 months. As soon as all the joints start disintegrating. Then you have to get a 3D printed part to fix them if you're out of warranty.  I have owned the logitech, the Steelseries Arctis 7 and the Arctis Pro. The Steelseries sets are better quality by far, and I have no idea the length you went to to make the mic on the Arctis 7 sound so terrible. Mine sounds way better than what you have sampled.",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-11T23:57:43.000Z',
#       'updatedAt': '2020-04-11T23:57:43.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/KXyT2EAaFNWwogbvMwvukSGU8XQ"',
#    'id': 'UgzWfEUzC7MVWoP3hLB4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/2tn6kSQGEMntDKsgtcX3sPxLr5Y"',
#      'id': 'UgzWfEUzC7MVWoP3hLB4AaABAg',
#      'snippet': {'authorDisplayName': 'wesley f',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJzttHscd1kLl1wEBRqHCOg5lETum4qi4W7q4w=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC5CIRWZ7K3d7uGcww_VcXxw',
#       'authorChannelId': {'value': 'UC5CIRWZ7K3d7uGcww_VcXxw'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'void pro wireless',
#       'textOriginal': 'void pro wireless',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-11T23:57:26.000Z',
#       'updatedAt': '2020-04-11T23:57:26.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/GGAbhPGcrJvRkDe68dp6h7D919A"',
#    'id': 'Ugz63g9xb6Cx-LmKpch4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/EflcuW6B_WLyPiSFiwzpj2VtV7E"',
#      'id': 'Ugz63g9xb6Cx-LmKpch4AaABAg',
#      'snippet': {'authorDisplayName': 'SIDHANT JASROTIA',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJx177DLSs_Wr2jtFHas7mNPiAMH0cRaFtzj3g=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCl6MHl192hwyjcFX8wEycaQ',
#       'authorChannelId': {'value': 'UCl6MHl192hwyjcFX8wEycaQ'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'All of them are shit,wtf linus',
#       'textOriginal': 'All of them are shit,wtf linus',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2020-04-11T23:56:48.000Z',
#       'updatedAt': '2020-04-11T23:56:48.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/6zcbPXvfN3nlMFIJeq3airkCJ94"',
#    'id': 'UgzBytT41dyqnK83i5N4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/I2AvATPmcLHM4okET1rvG0PZaQg"',
#      'id': 'UgzBytT41dyqnK83i5N4AaABAg',
#      'snippet': {'authorDisplayName': 'THE-ULTIMATE-MO',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJyGoqRNkY9CDgDb-RruGaNHhByk3grIbwI5Vw=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCMSJUw6e3g_uuq_PMV_SuLg',
#       'authorChannelId': {'value': 'UCMSJUw6e3g_uuq_PMV_SuLg'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'Having fun using psnow and playing Spider-Man. Though it does stutter and I have to play in windowed mode cause it doesn’t scale to 1440p only 720/1080',
#       'textOriginal': 'Having fun using psnow and playing Spider-Man. Though it does stutter and I have to play in windowed mode cause it doesn’t scale to 1440p only 720/1080',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-11T23:56:24.000Z',
#       'updatedAt': '2020-04-11T23:56:24.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/EntsjdO9Q_l3VIKii0C9-sIfxdE"',
#    'id': 'UgwBqE3HzQCA17FC1PN4AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/Ra5DkovWg1iBC8AiLuhBdEBspho"',
#      'id': 'UgwBqE3HzQCA17FC1PN4AaABAg',
#      'snippet': {'authorDisplayName': 'xXCraziiPandaXx',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJxyyCwFSSSy58NKCixBxF7aKX6tNriaAb7H-Q=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCSc8cl5Jf9LMofvpzJ0s1zA',
#       'authorChannelId': {'value': 'UCSc8cl5Jf9LMofvpzJ0s1zA'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': "i like you doing reviews. nice to see a different face other than Linus'.",
#       'textOriginal': "i like you doing reviews. nice to see a different face other than Linus'.",
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-11T23:55:51.000Z',
#       'updatedAt': '2020-04-11T23:55:51.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/5sFoVt_dB2uLsBG5iRm6l3b061U"',
#    'id': 'Ugxk5r6NBzs0NzXVWt94AaABAg',
#    'snippet': {'videoId': 'R5dPvW7NMJE',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '"tnVOtk4NeGU6nDncDTE5m9SmuHc/ECfpNGXsIb7mbarh1oz5BdXQGD0"',
#      'id': 'Ugxk5r6NBzs0NzXVWt94AaABAg',
#      'snippet': {'authorDisplayName': 'Rohin Hans',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJyZ-Rmp-P9m2eQYiJbrn6ZeY5HEMFZLrRebTg=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCbxyVMUlQ7oEPGsKTY1ewrA',
#       'authorChannelId': {'value': 'UCbxyVMUlQ7oEPGsKTY1ewrA'},
#       'videoId': 'R5dPvW7NMJE',
#       'textDisplay': 'What about the steel series pro?',
#       'textOriginal': 'What about the steel series pro?',
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-04-11T23:55:41.000Z',
#       'updatedAt': '2020-04-11T23:55:41.000Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
All_Comments = data["items"]
# All_Comments[5]["snippet"]["topLevelComment"]["snippet"]["textDisplay"]

comment_count = 1
for comment in All_Comments:
    current_comment = comment["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
    print(f"Comment #{comment_count}: {current_comment}")
    comment_count = comment_count + 1
# Out:
# Comment #1: Corsair virtuoso was such a huge disappointment. Great mic audio. Awesome build quality.
#
# However completely unuseable audio since it has excessive artifacting.
#
# Compared against the cloud wireless and the arctis. Corsair was the only one with the issue
# Comment #2: i dont understand  why all headset videos ignore the Corsair VOID RGB,  Its an great headset and the logitech G935 is  an joke compare to this
# Comment #3: i still use my senheiser gsp 500
# Comment #4: I don't get the deal with wireless. I have some of the first run of Audeze Mobius,  always run wired
# Comment #5: Confused as to why the Arctis pro wireless wasn’t included when the 7 was. Not the “best” steel series has in their lineup but okay
# Comment #6: DO NOT GET THE LOGITECH  G935!!!
# Speaking from experience with them they are NOT great at all as the range on them suck like only moving from one room to another can cause them to drop out, they are Very bulky and somewhat heavy causing long sessions to wear on the top of your head. As mentioned in the video they are of poor quality as they creak A LOT and you end up hearing it if you are say having a snack and the side panels do sometimes come off when slightly knocked.
# Im not happy with them at all and im now looking for something better but still havent found anything that could match the decent sound of the G935 (the only good thing going for them) and im kinda looking at the CORSAIR HS70 PRO but they dont have true 7.1 so yeah I dont know.
# Comment #7: I use byerdynamic dt 770 pros and that won't change for a while
# Comment #8: I use a pair of Bose AE2 headphones I've had for a long time, paired with a Samson GoMic USB mic. Great audio in and out. Almost every headset mic I've heard is awful.
# Comment #9: sorry but those logitech headphones are absolute trash, this video is a writeoff due to this. Not to mention battery life of them are awful, connection issues suck, sound is terrible and comfort compared to the hyperX is subpar.
# Comment #10: the logitech one is horrible, the materials are bad they break easy, sound is horrible, software doesnt help at all, microphone is also weak
# Comment #11: Steelseries Arctis Pro Wireless are by far the best wireless gaming headphones
# Comment #12: Arctis Pro wireless should’ve been included
# Comment #13: I saw you in a commercial
# Comment #14: what about the gsp 670 from sennheiser?
# Comment #15: It's not a famous choice but Audeze LCD-GX is a gaming headphone....
# Comment #16: I'm just rocking my Logitech G Pro X headset and I have an Anker Soundsync Bluetooth 5.0 reciever/adapter for whenever I want to use it wireless. Overall it coated me about £110 so about $140
# Comment #17: I'm thinking keep the wire and use those HyperX Cloud II for another decade
# Comment #18: i have the logitec 935 and a little heads up mileage may very. the wireless function died in less than a year and i'm stuck using a aux cable for sound, furthermore when it starts dying you'll notice it by the syncing problem with audio levels and quality.
# Comment #19: WHERE IS SENNHEISER?
# Comment #20: How do the RIG 800LX compare to these headsets?
# Comment #21: did the chance of equalizers in for my astro a50 like you guys had in the forum post and a hole new world opened up for me
# Comment #22: the thing with logitec, my SO has been using them for ~5 years now, not a single headset has managed to reach it's end of warranty before it dies, she is now on her 5th set having been replaced and now this set is dying as well.
# their warranty however is superb and they just get swapped over, it's the hassle of having to DO it though.
# it's just annoying I can't help but why why they keep dying.
# Comment #23: I've had the Logitech G935 for a half year now. The qreekyness is something me and my friends haven't encountered yet with it. Sound is great and a lot of customisable options. Though the battery can be a tad bit disappointing.
# Comment #24: You fellas seriously missed the boat with this one. 935's over A50's?! You've got to be kidding me. They sound worse, they're way less comfortable (45 minutes of use and my ears were killing me). They also feel unbelievably cheap. A50's sound even better when you replace the cloth ear pads with the closed variant.
# Comment #25: There’s no way that they used the virtuoso for more than an hour. The most uncomfortable headset ever.
# Comment #26: I recommend just getting some good Headphones, like the Philips SHP 9500, and a USB or powered XLR Mic for best sound quality on your and your friends side. Stay away from Headsets!
# Comment #27: Wouldthere be any issues with them working on next generation of consoles?
# Comment #28: Why are these "gaming" microphones always shitty as hell? Always clipping and distorted. Why can they not just sound at least acceptable? Is it so hard?
# Comment #29: This episode would have been perfect for a ridge wallet ad, considering that intro.
# Comment #30: Arctis pro wireless is way better than the a 50 it isn’t in this video and i use it. It’s so nice!
# Comment #31: I love this Channel but this video was lacking. Don't put best in the tittle when you are using such a low sample pool.
# Comment #32: I have a Wh1000xm3 with a vroom microphone and works great.
# Comment #33: i've been an avid music listener for well over a decade. i've spent anywhere between $10 to $150 on headphones and earphones. the best pair i've found build quality wise (that're still manufactured) is actually the best buy brand insignia bluetooth over ear headphones. my first pair of these lasted 4 years before i accidentally sat on them. my second pair lasted 3 years before i accidentally crushed them while falling. i'm on my 3rd pair now. can get for $20 if patient for a sale. if impatient it's $40. plug this into the best buy site: NS-CAHBTOE01....the only real con i can think of is that the lowest 2 volume settings while on bluetooth differ a bit too much.(too quiet vs slightly too loud) can still overcome that problem with detachable aux cord though.
# Comment #34: What is the best headphone under 30$ to 45$
# Comment #35: I really do hope that people understand that they mean gaming branded headsets in this video just in case before the same obnoxious gaming headset hate circlejerk starts and people start masturbating to their Beyerdynamics headphones with a ModMic.
# Comment #36: Are we going to get a super budget headset video? Thx
# Comment #37: People using the word "Audiophile" with wireless gaming headphones  - Yeah
# Comment #38: The last 2 top of the line Logitech wireless headsets my family has used have all failed within the first year of ownership.  This failure rate was previously unheard of for that brand, and as a result, I strongly suggest people look elsewhere, especially in terms of headsets (wireless or otherwise).
# Comment #39: Linusb-c?
# Comment #40: Shouldn't have used the word "best" and "worst" if you're going to include items that are "okay" or "meh"
# Comment #41: wish you did the hyperx cloud mix instead of the crappy flight
# Comment #42: Arctis Pro, HS 70, GSP 670, Nari and so much more not even at least mentioned?
# Comment #43: Pulseway's advert features Linus 🤣🤣🤣🤣
# Comment #44: He had the mic upside down on the Arctis
# Comment #45: That Logitech mom photo is hilarious
# Comment #46: Is it just me or did we never get this on Floatplane? I don't remember it at all.
# Comment #47: I got the arctis 7 because the mic sounded the best for the price IMO. Its nice to not need an external mic all the time if you want to just do a quick and easy livestream or something.
# Comment #48: the head band on the arctis at least the once i have are metal you can bend them back a fair bit a few times and it takes away the pressure issue.  suprised you never mentioned if you have a big head that band does not mater how much you adjust it because you have that metal thing grinding in you head.
# Comment #49: I have had three pairs of G935s between me and my old lady. The experience made me never want a logitech headset (or keyboard) ever again. I also had the Logitech G35s. Only thing I can say about Logitech is thank god their customer service and RMA dept's are on the ball because 2/10 logitech products you buy will require an RMA within 6 months. I had these problems back on the G510 all the way up to the G810 until I caved and went away from them. I daily drive Steelseries Arctis headphones for all my devices now. I have owned 500 dollar sennheiser headphones, audio-technicas, AKGs, Logitech and Turtle Beach headsets over the years and the Steelseries Arctis 3 BT and Arctis Pro Wireless have both served me issue free with quality sound from day one. I sleep with them on, I bike with them on (no helmet, sorry safety captains). I use them on my desktop, laptop, phone, switch. I used them for work instead of the crappy Sabra's IT gives you. Amazing headsets. Would love to see you guys test a broader range of headsets and headphones in the office with some better methodology.
# Comment #50: Would of been nice if you ranked the headsets at the end. Short video for review.
# Comment #51: i have wired cuz of my blue yeti mic srry but any wireless headset is meh to me i still like wired anything
# Comment #52: I have those Corsair's and I'm very happy.
# Comment #53: We need this video but with just wired headphones none of the "gaming" ones with a mic either.
# Comment #54: Love these types of "worthwhile buy" videos, but this one missed the mark. Too many missing great wireless headsets. For the ones that were on here, I have personally purchased, used, and sold each of them except for the Arctis 7, which was the only one I could tolerate keeping. Recently bought the Arctis pro wireless and it is fantastic, minus the price. Is it worth $300+? No... but I haven't used anything better yet. I still want to try the new Sennheiser 670 headset before choosing between the two. Go Arctis 7 or none of these.
# Comment #55: Most of the points you made in this video don’t pertain to console players who dont adjust eq😂
# Comment #56: Corsair MIC sound?
# Comment #57: Steelseries arctis pro wireless
# Comment #58: Using SteelSeries Siberia 800 for over 3 years. Sounds great to me, has option to use as wired headset, long battery life at about 20 hours, and has 2nd battery with charger in base. No software bs either, plug and play, all controls are in menus in base station. Comfortable to wear for a few hours at a time. Great range, can get most of a 1000 sq. ft. 1 story house before dropping out (70-100 feet thru walls, more in open space). Got them when they were on sale for about US$180.
#
# Only downsides I've had with it is the clamps that hold the cup bracket to the headband can break or crack (fixed with Velcro tape wrapped around), the mini-B USB connector on the base station can be a bit fragile, and the plastic wrap around the retractable mic is cracking in a few spots and almost freely spins around.
#
# Would still buy them again.
# Comment #59: i was wondering where rig was :D!!
# Comment #60: corsair void pro  here
# Comment #61: Better to just get something from Audio Technica or Sennheiser and buy a modmic than get a gaming headset,
# Comment #62: I think they got this wrong in a few ways. They could have replaced most if not all of these headsets with the Razer nari ultimates. And your case for Logitech was super weak compared to what you said about the Astros. But naris for sure should have been on the list
# Comment #63: Linus and team, I have enjoyed your videos for years. I just did my first PC mod ever thanks to you 8<16gb ram + 1tb ssd to my i7 8th gen 1050 laptop. You guys have helped me thru homelessness, drug abuse, depression etc . and I hope you all continue to reap the rewards of your labor for years to come.
# Comment #64: Kinda surprised you didn't include the Audeze Mobius.
# Comment #65: no razer nari ulti's?
# Comment #66: Give
# Comment #67: WHAT! PORTUGUESE SUBTITLES? Nice! 😋
# Comment #68: Logitech g935 is one of the worst headsets I’ve used lmfao
# Comment #69: I've g930 and I like it, besides the known issue with bad microphones
# Comment #70: I was disappointed, because I just got new headphones last month, and I would have loved to see one of these rundowns.  That is, until you recommended the headset I bought anyway.  Good to see that my research came to a reasonable conclusion.
# Comment #71: I have been using the A50's for almost 5 years. My brother used Logitech's wireless headset, The older steelseries wireless headset, and two other wired ones, he is now on the Hyper X, But my point being, this review does not tell you how durable the A50's are, also I replaced my ear pads for 20$ a couple of months ago (because they had lots of gamer sweat) but I expect a couple more years from these beasts, I can't recommend the A50's enough. If you got the dough, they are the most premium headset you will buy. Also I think the quality is pretty high, again hard to say cause Iv've had them for so long. Also Also, 300$/5 years = 60$ a year. pretty good investment.
# Comment #72: Why do all the mics sound so bad? I'd expect more at this price range, damn.
# Comment #73: It's a shame that there was so little said about the Mic quallity. I wanna like the G935 but that mic quallity is soooooo terrible. And the Virtuoso sounds so good mic wise (for wireless).
# Comment #74: Logitech always make a reasonable wireless headphone for price but god damn does their software let it down time after time. Always getting dropouts/disconnects randomly no matter where the dongle would be or it would just forget your settings on reboot or not find the headset at all. All these things come out of the closet a year or so after owning one. Sorta like buying a Canon printer vs Brother, the Brother rids away the headache inducing wars you'll have with the flashier known brand in Canon even for a similar price point with some lesser features but they at least work across the board hardware and software wise very unlike the Canon which is all snake oil.
# Comment #75: No Audeze Mobius in the comparison? Sad :(
# Comment #76: We need a video where you check active noise-cancelling gaming headsets. I know there is a active noise-cancelling headphones video, but I'm talking about a headset (with mic). Thanks
# Comment #77: All the mics sound like trash as that's a limitation of wireless transmitting and receiving audio at the same time that coupled with the form factor, you can't have a super small mic sound super nice without a lot of money. So if it can't sound due to bandwidth limitations good might as well make it look good which only makes them sound worse as they don't spend money into the mics. Just use a dedicated mic, you can even run that wireless too but it really improves the sound.
# Comment #78: Sold out of large mystery shirts. Guess I'll settle for only folding
# Comment #79: I have the gen 3 Astro a50s and they are dope for Xbox! I just wish they had the eq app for Xbox and not just pc.
# Comment #80: Linus pls get me a gaming pc I’m bored in the house and I’m in the house  bored 😐
# Comment #81: Plot twist : None
# Comment #82: Razer:Am i a joke to you?
# Comment #83: Cloud flight is clearly the best people!😃 he is lying. I can verify.
# Comment #84: What about not turning the sound on?
# Comment #85: Been using Plantronics RIG 800 for pc & xbox with Atmos. No complaints.
# Comment #86: Why don't people understand that "gaming" headphones are a gimmick?
# Just get regular open back headphones instead of these!
# And regular pair of headphones is gonna be much better than these at the same price.
# Eg: Get a Philips SHP 9500, a Sennheiser HD599, HD68x, a Beyerdynamic Dt770 Pro.
# Or heck. Get any  headphones which isn't "gaming", and save a lot of money. "gaming" headphones sound trash, look bad, are built like a toy, mic suck.
# Comment #87: I bought my sennheisers 5 years ago and other than new pads and cable replacement because of heavy use they work great. Absolutely no reason to upgrade considering their sound quality and the 2x-3x price for worse or equal quality wireless headphones. Plus headset mics are trash, get a desk mic if you're investing that much money into your setup.
# Comment #88: arctis 7 instead of arctis pros????
# Comment #89: Just got the g533 from logitech and they are super squeaky and don't deal well with loud noises but range is great and fit is amazing. tried corsair h70 but their cups weren't deeper at the back so my ears didn't fit.
# Comment #90: Beware of Logitech ghub, it's really not a full replacement for lgs and it's very buggy to this point
# Comment #91: The mics are all shit, the hyperx was the best... but still bad kinda bad.
# Comment #92: Wired video next pls
# Comment #93: I personally don't really see the need for a wireless headset, headphones sure cos I wear them walking to work and stuff, but a headset? What's the point, when I'm gaming I'm literally just sat at my desk so why do I need a 30 foot range when I'm not going anywhere? Gimme open back wired headphones connected to a DAC/amp any day.
# Comment #94: What song it is at 3:05 in the background?
# Comment #95: The logitech set should last about 3 to 6 months. As soon as all the joints start disintegrating. Then you have to get a 3D printed part to fix them if you're out of warranty.  I have owned the logitech, the Steelseries Arctis 7 and the Arctis Pro. The Steelseries sets are better quality by far, and I have no idea the length you went to to make the mic on the Arctis 7 sound so terrible. Mine sounds way better than what you have sampled.
# Comment #96: void pro wireless
# Comment #97: All of them are shit,wtf linus
# Comment #98: Having fun using psnow and playing Spider-Man. Though it does stutter and I have to play in windowed mode cause it doesn’t scale to 1440p only 720/1080
# Comment #99: i like you doing reviews. nice to see a different face other than Linus'.
# Comment #100: What about the steel series pro?
