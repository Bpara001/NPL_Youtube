# %%
import os
import json
import googleapiclient.discovery
import googleapiclient.errors
import google_auth_oauthlib.flow
import requests
  
api_key="AIzaSyBnQLWZiH4u9fSeO2whrAy2dx5na7Pb1tU"
video_id="R5dPvW7NMJE"
url = f"https://www.googleapis.com/youtube/v3/commentThreads?key={api_key}&textFormat=plainText&part=snippet&videoId={video_id}&maxResults=100"

data = requests.get(url).json()

# %%
#data

# %%
All_Comments = data["items"]
# All_Comments[5]["snippet"]["topLevelComment"]["snippet"]["textDisplay"]

comment_count = 1
for comment in All_Comments:
    current_comment = comment["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
    print(f"Comment #{comment_count}: {current_comment}")
    comment_count = comment_count + 1
# Out:
# Comment #1: I expected that they'll talk about the delay of headset since these are GAMING headphones. Disappointing.
# Comment #2: Logitech g935 for me
# Comment #3: Who tf is this dude?
# Comment #4: ooohhh more than a couple years now
# Comment #5: No turtle beach
# Comment #6: Stfu about Squarespace, I dont need a motherfucking website... wtf....
# Comment #7: My favourite headset is not mentioned here, but I am going to mention it. The SteelSeries Arctis Pro Wireless. They sound amazing and have a very good range and other features such as a user-replaceable battery and equalizer.
# Comment #8: Am I only hear trying to get a funny mic for my xbox or is it just me
# Comment #9: This is 120 on Amazon. It is the cheapest in this line-up
# Me: starts sweating
# Comment #10: Turtle Beach makes horrible headphones
# Comment #11: I need a headset that is glasses friendly. Many of my headsets makes the side of my head hurt after a prolonged gaming session.
# Comment #12: 1:18 is this the only headset that offers auto turning off speakers when headphones come on ?
# Comment #13: what about the Turtle Beach Elite Atlas Aero
#
# ist that any good?
# Comment #14: You should have used the Cloud Flight S
# Comment #15: Steel series are junk. They are heavy and the speaker housing that holds the removable battery is made of cheep flimsy plastic. I have gone back to my $13 corded headphones. I liked everything about the steel series, but having learned that the housing is made of plastic, I would tell people to stay away from these. If the housing was beefed up aluminum or even titanium and cost $250.00 then I would have to say it would be hard to beat them. As they are made now, total junk.
# Comment #16: I’m looking for good headsets that don’t hurt the top of my head after gaming for a long time. Any recommendations?
# Comment #17: where is linus
# Comment #18: how is the logitech on comfort?
# Comment #19: When it said the $120 was one of the cheaper option I clicked off
# Comment #20: I cannot recommend the G935, I have the G933's and I'm about to return the second pair due to one ear going out, the first pair always had pairing issues and was a big pain
# Comment #21: If you have the Logitec headphones use the EQ they set. It makes them sound SOOOOOOOOO much better.
# Comment #22: I need a suggestion. Need a pair of wireless. Headphones for gaming and Working out (so sweat proof). I cant seem to find sweat proof headphones that do not have a sound delay when it comes to games. What do you guys suggest?
# Comment #23: Y U NO Sennheiser GSP 670!?
# Comment #24: I own the g935s great set of cans
# Comment #25: Artis have the worst mic of all, and the worst customer service, 6 months later and moving to the Corsair Virtuoso..  Steel Series is just a waste of money.
# Comment #26: do NOT buy g935 logitech headset, they are GARBAGE.
# Comment #27: Me watching with subtitle because my headset broke
# Comment #28: Virtuoso's band is the most uncomfortable I've ever used. After using for extended periods, the top of my head hurts a lot. Sound is great, but even with these as my daily drivers, I can't recommend until they fix that band.
# Comment #29: Im already happy with my headphones bc i can earape without using another type of item
# Comment #30: Got the g935 for 109 sounds great!
# Comment #31: yall should make one of these videos directed towards us console peasants that are without plugins
# Comment #32: Does the G935 have the same design flaw as they G933 with failing power switch over time? As it's seems to be the same switch?
# Comment #33: What about the arctis pro wireless... They are basically a better arctis 7.
# Comment #34: I love my G935s
# Comment #35: what about razer kraken?
# Comment #36: one nice thing about the a50s is that if yours does for some reason break, or in my case, the batteries wont hold a charge and they are worn out in general (mine were 5 years old when i replaced em) you can buy just the headset on amazon or ebay or whatever and sync them to the transmitter effectively getting a brand new set for less than full price. I got a pair on amazon for $100 which considering how much i love these headphones are easily worth it imo.
# Comment #37: Sub $100 Gaming Headset round-up next time? Corsair HS70 is a great choice!
# Comment #38: Logitech G935 va astro 50 gen 4 ??? How i chose
# Comment #39: I already have a pair of Logitech G933 and I very soon need to replace them as they are going old in some places sadly because i love them so yeah if its just the G935 i will go with next time will tell
# Comment #40: the HyperX Cloud Flight are just dog poo sold as headsets
# Comment #41: The Sennheiser GSP 670 stomps all those wannabe gaming headsets into the ground! Logitech doesn't even come close to the quality and sound of the GSP 670,
# And you voted it the best headset? Really? Hahaha, of course! How much did Logitech pay you for this video?
# Comment #42: Who else is watching this after one side of their headphones stopped working like mine?
# Comment #43: Literally none of them are available in my region (India)
# Comment #44: how is the lucid sound 35?
# Comment #45: I cant believe this is the list of 'the best' when it all looks like entry-mid level headphones?
# Comment #46: Corsair Hs60 , should I return them? Mic is wayyyy to quiet and listening to music sounds like I'm in a tunnel... anyone else?
# Comment #47: You didn't talk about Astros software
# Comment #48: Great reviews, shame there all based on pc use. I've owned and sent back all of these except for the logitech. All of them sucked on ps4 compared to my daily lucid sound ls41.
# Comment #49: The Corsair Void Elite Rgb wireless is 🐐🐐
# Comment #50: No razer?
# Comment #51: just me or did the logitech headset mic sound trash
# Comment #52: Criminal that the Arctis Pro Wireless is not included in this review.
# Comment #53: The Mic on the G935 is noticeably worse than the Corsair Virtuoso, like, way worse in your own test. The Virtuoso's are also a lot more expensive, but if mic usage is your main concern, or even a close secondary, I have no idea why you would recommend the G935 and not the Virtuosos. Even the Cloud Flight sounds better on the mic.
# Comment #54: Got the logitech, comoared to a50, ur are high a50s are better
# Comment #55: FORGOT ABOUT RAZER!
# Comment #56: Do these work for xbox
# Comment #57: my headset didnt get tired threw it at the wall at mach 5
# Comment #58: in the comments are the information i need lol
# Comment #59: arctis 7 are 180€ here !!!!!!!
# Comment #60: If a headset is just okay, why even mention it?
# Comment #61: The problem I have had with Logitech wireless headphones over the years, 4 of them at this point, is the USB charging input eventually breaks in only a few years and the headphones neither charge nor work wired and thus are useless from there on out.
# Comment #62: I've had my a50s for a couple months now and the buttons on the side are messing up and ruining the audio. I switched to the a40s but they still after about an hour of messing with them have not successfully connected with my Xbox but work 100% with my computer no issues at all
# Comment #63: Logitech G935 wireless or the Corsair Virtuoso wireless
# Comment #64: The information was very useful, now I will know which headphones to buy
# Comment #65: I’ve been using a 5 dollar headset from five below and they work pretty dam good and haven’t had any problems so far. However I am interested in getting a nice pair to see how they compare
# Comment #66: The microphone of the G935 is faaasr more better... Even my 635 did it better
# Comment #67: No Arctis pro wireless? This vid just came out!
# Comment #68: 0:07 wireless sounds like downgrade
# Comment #69: Okay YouTube i'll watch the video!
# Comment #70: I just don’t understand why the Sony wh1000x m3 don’t work with PlayStation
# Comment #71: My Corsair just died after 3.5 years and wasn't offered a discount on next headset so looking for a new group.
# Comment #72: Anything called a ‘gaming headset’ will sound shit, it’s all gimmicky junk aimed at gamers who don’t know any better.
# Comment #73: who da fook is that guy
# Comment #74: Do any of the other headsets also have a separate chat/game audio like the arctis 7?🤔 Cuz that function is a frickin lifesaver
# Comment #75: i have some wireless headphones and they work really well they are made by a company called cowin
# Comment #76: G935 and G933s, are they the same?
# Comment #77: what is the best if the creeky option, wasn't an option? also any good wireless mod mics?
# Comment #78: the mics all sound bad
# Comment #79: I definitely cannot recommend the Corsair Virtuoso RGB. The build quality is nice and such, but the listening quality sucks hard and the iCue is even worse. It is so buggy, especially when you switch from wired to wireless from time to time when the battery is low, which happens at least twice during the day (8 to 12 hrs a day) and you can't turn off RGB. It is really a bummer because the whole thing looks stellar, but that's really the only positive.
# Comment #80: Hi friends, here in the store I saw headphones https://alex150.selz.com advise to take?
# Comment #81: I hate mics that have leather ear-foams it’s just not comfortable... turtle beach wireless mic is so underrated
# Comment #82: Anyone have the virtuoso’s?  How are they?
# Comment #83: Just buy a g pro x and call it a day. It has the best mic quality,sounds great,comfortable,and only costs about 150 Canadian bucks
# Comment #84: Thank you, this was helpful in trying to find some new headphones. Although I would have preferred a, 'quality > money', option.
# Comment #85: is there any fuckin headset for people with glasses?
# Comment #86: Where is Logitech g pro X?
# Comment #87: Headache 🤦🏾‍♀️
# Comment #88: I got G935 and I would recommend them just to everybody - I have never heard so powerful headphones in my life. 50mm drivers will make you feel every sound.
# Comment #89: WTH, HyperX Cloud Flight is widely praised, and you call it... the worst??
# Comment #90: I have an arctis 7 and the mic is not that bad
# Comment #91: I have the hyper x headphones. They are under rated in the video. They are pretty good and would suggest them since they are also a good price.
# Comment #92: why didn't you review the steelseriers arctics pro wirles?
# Comment #93: G hub sucks ass, can anyone help me with how it always shows my g935's as not connected no matter what I do. What I've tried: reinstalling software deleting software files afterwards, uninstalling drivers and re-pairing headphones to dongle all while restarting PC.  I'm hard returning these pieces of crap, I can't even see their damn battery percentage let alone program the buttons
# Comment #94: Do not buy a  g933 Artemis spectrum. Not worth the coin. Constant dramas with their software and the headsets restart randomly. Such a shame because they used to be the mutts nuts logitech. Had an astro a40 with the mix amp. The audio was crackly when using the mix amp and the headsets are heavy, hot and apply pressure to your ears and head which gets sore after a while. Otherwise if anyone can recommend I'm all ears....
# Comment #95: I tried the virtuoso and it started getting uncomfortable after 10 mins
# Comment #96: You talked about the arctis 7 and not the pro?
# Comment #97: None of the headsets are good. If you are watching this review from India, then check the Amazon price for the Logitech headset. Only 39k🤣😂
# Comment #98: how do these compare to the alienware wireless?
# Comment #99: Kids just get Astro A-40 or A-50
# Comment #100: you can't be serious about the clear chat EQ on the virtuoso. Everything sounds like a robot speaking trough a walkie talkie

# %% [markdown]
# ## Other Call Method

# %%
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = api_key

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey = DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet,replies",
    maxResults = 100,
    videoId="oiWq85NVivw"
)
response = request.execute()

response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'DqTP51m8vSkMO4bCgK-eI4uoCgg',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 100},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'tZK2Q3gZy57HpzEzVRnIjVCTAx8',
#    'id': 'UgyB-QQ36mmRqqQ8I214AaABAg',
#    'snippet': {'videoId': 'oiWq85NVivw',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '4L2zSjrkwoO0PRQla-5fzqwahQI',
#      'id': 'UgyB-QQ36mmRqqQ8I214AaABAg',
#      'snippet': {'videoId': 'oiWq85NVivw',
#       'textDisplay': 'like',
#       'textOriginal': 'like',
#       'authorDisplayName': 'Victor Pinheiro',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/a/AATXAJx-XK4qF28FECK1Ha08wQQpMm3IHVB3ansiqTEVgA=s48-c-k-c0xffffffff-no-rj-mo',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCV4XBKyZYBJ2fu6NgchJRsw',
#       'authorChannelId': {'value': 'UCV4XBKyZYBJ2fu6NgchJRsw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2019-05-22T14:21:20Z',
#       'updatedAt': '2019-05-22T14:21:20Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %%
data = response
All_Comments = data["items"]
# All_Comments[5]["snippet"]["topLevelComment"]["snippet"]["textDisplay"]

comment_count = 1
for comment in All_Comments:
    current_comment = comment["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
    print(f"Comment #{comment_count}: {current_comment}")
    comment_count = comment_count + 1
# Out:
# Comment #1: like

# %%
nextPageToken = data["nextPageToken"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-8df01be67f9a> in <module>
# ----> 1 nextPageToken = data["nextPageToken"]
#       2
#
# KeyError: 'nextPageToken'

# %%
nextPageToken

# %%
request = youtube.commentThreads().list(
    part="snippet,replies",
    maxResults = 100,
    pageToken = nextPageToken,
    videoId="nlmbfw9xWTk"
)

response2 = request.execute()

response2

# %%
data = response2
All_Comments = data["items"]
# All_Comments[5]["snippet"]["topLevelComment"]["snippet"]["textDisplay"]

for comment in All_Comments:
    current_comment = comment["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
    print(f"Comment #{comment_count}: {current_comment}")
    comment_count = comment_count + 1

# %% [markdown]
# ## Get all comments

# %%
#Run this section once, everything will be saved in All_Response in temrs of a list of dictionaries
#This way you shouldn't need to use more calls then you usually might

import os
import json
import googleapiclient.discovery
import googleapiclient.errors
import requests
import pandas as pd
from config import api_key


#Insert video ID here
videoID = "J8OBoOkw_-g"
All_Response = []


os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"
All_Comments = []
All_Username = []
nextPageToken = ""

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = api_key

youtube = googleapiclient.discovery.build(api_service_name, api_version, developerKey = DEVELOPER_KEY)

#First Run
request = youtube.commentThreads().list(
    part="snippet,replies", 
    maxResults = 100, 
    videoId=videoID)

response = request.execute()

All_Response.append(response)

#If response comes back with a nextPageToken, add it as next page token. Just in case there's less than 100 comments
try:
    nextPageToken = response["nextPageToken"]
except:
    pass

#Iterate through all comments, add it to the list
comments = response["items"]
for comment in comments:
#     current_comment = comment["snippet"]["topLevelComment"]["snippet"]["textDisplay"]
    All_Comments.append(current_comment)
    
    
#If nextPageToken exists, run this loop. In the loop, nextPageToken will be renewed if there is more than 100 comments
while nextPageToken:
    request = youtube.commentThreads().list(
        part="snippet,replies",
        pageToken = nextPageToken,
        maxResults = 100,
        videoId=videoID
    )
    response = request.execute()
    
    All_Response.append(response)
#     comments = response["items"]
#     for comment in comments:
#         current_comment = comment["snippet"]["topLevelComment"]["snippet"]["textOriginal"]
#         All_comments.append(current_comment)
        
    try:
        nextPageToken = response["nextPageToken"]
    except:
        break

# %%
response["items"][5]["snippet"]["topLevelComment"]["snippet"]

# %%
#Breaks down username and comments. This is the section to test run all the responses and see what kind of results should be saved.

All_Comments = []
All_Username = []
for response in All_Response:
    comments = response["items"]
    for comment in comments:
        username = comment["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"].encode("ascii","ignore").decode("ascii")        
        current_comment = comment["snippet"]["topLevelComment"]["snippet"]["textOriginal"].encode("ascii","ignore").decode("ascii")
        All_Username.append(username)
        All_Comments.append(current_comment)

# %%
count = 0

for i in range(len(All_Comments)):
    print(f"{All_Username[i]}: {All_Comments[i]}")

# %%
import pandas as pd
Comment_Section = pd.DataFrame()

Comment_Section["Username"] = All_Username
Comment_Section["Comment"] = All_Comments

# %%
Comment_Section.head()

# %%
Comment_Section.to_csv(f"Youtube_Comments/{videoID}.csv",encoding = "utf-8")

# %%
import json
import nltk
import random
from nltk.classify.scikitlearn import SklearnClassifier
import pickle
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC, LinearSVC, NuSVC
from nltk.classify import ClassifierI
from statistics import mode
from nltk.tokenize import word_tokenize



class VoteClassifier(ClassifierI):
    def __init__(self, *classifiers):
        self._classifiers = classifiers

    def classify(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)
        return mode(votes)

    def confidence(self, features):
        votes = []
        for c in self._classifiers:
            v = c.classify(features)
            votes.append(v)

        choice_votes = votes.count(mode(votes))
        conf = choice_votes / len(votes)
        return conf


documents_f = open("documents.pickle", "rb")
documents = pickle.load(documents_f)
documents_f.close()




word_features5k_f = open("word_features5k.pickle", "rb")
word_features = pickle.load(word_features5k_f)
word_features5k_f.close()


def find_features(document):
    words = word_tokenize(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features



featuresets_f = open("featuresets.pickle", "rb")
featuresets = pickle.load(featuresets_f)
featuresets_f.close()

random.shuffle(featuresets)
print(len(featuresets))

testing_set = featuresets[10000:]
training_set = featuresets[:10000]



open_file = open("originalnaivebayes5k.pickle", "rb")
classifier = pickle.load(open_file)
open_file.close()


open_file = open("MNB_classifier5k.pickle", "rb")
MNB_classifier = pickle.load(open_file)
open_file.close()



open_file = open("BernoulliNB_classifier5k.pickle", "rb")
BernoulliNB_classifier = pickle.load(open_file)
open_file.close()


open_file = open("LogisticRegression_classifier5k.pickle", "rb")
LogisticRegression_classifier = pickle.load(open_file)
open_file.close()


open_file = open("LinearSVC_classifier5k.pickle", "rb")
LinearSVC_classifier = pickle.load(open_file)
open_file.close()


open_file = open("SGDC_classifier5k.pickle", "rb")
SGDC_classifier = pickle.load(open_file)
open_file.close()




voted_classifier = VoteClassifier(
                                  classifier,
                                  LinearSVC_classifier,
                                  MNB_classifier,
                                  BernoulliNB_classifier,
                                  LogisticRegression_classifier)



# Sentiment function only takes one parameter text.
# From there, we break down the features with the find_features function.
def sentiment(text):
    feats = find_features(text)
    return voted_classifier.classify(feats),voted_classifier.confidence(feats)
#https://github.com/aalind0/NLP-Sentiment-Analysis-Twitter/blob/master/sentiment_mod.py
